# %%
import os
import math
import torch
import bitsandbytes as bnb
import torch.nn as nn
from safetensors.torch import load_file
import matplotlib.pyplot as plt

# %%
@torch.no_grad()
def _get_mask_prune_magnitude(
    W,
    sparsity_ratio: float,
    prune_n: int,
    prune_m: int,
    largest: bool,
    offload: bool,
) -> torch.tensor:
    """
    get mask for pruning based on magnitude.
    largest: if True, prune the largest weights, otherwise prune the smallest weights.
    """
    W_metric = torch.abs(W)
    if prune_n != 0:
        W_mask = torch.zeros_like(W, dtype=torch.bool)
        for ii in range(W_metric.shape[1]):
            if ii % prune_m == 0:
                tmp = W_metric[:, ii : (ii + prune_m)].float()
                idx_to_keep = torch.topk(tmp, prune_n, dim=1, largest=largest)[1]
                W_mask.scatter_(1, ii + idx_to_keep, True)
    else:
        if largest:
            thresh = torch.sort(W_metric.flatten(), descending=True)[0][int(W.numel() * sparsity_ratio)].cpu()
            W_mask = W_metric >= thresh
        else:
            thresh = torch.sort(W_metric.flatten())[0][int(W.numel() * sparsity_ratio)].cpu()
            W_mask = W_metric < thresh
    if offload:
        return W_mask.cpu()
    else:
        return W_mask

# %%
@torch.no_grad()
def decomposeW2LinearWeightLR(W: torch.Tensor, r: int):
    assert len(W.shape) == 2
    assert r in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512]

    M = W.to(dtype=torch.float32)
    U, S, Vh = torch.linalg.svd(M, full_matrices=False)

    # Extract the top r singular values and corresponding singular vectors:
    # U_r -> d x r matrix (top r left singular vectors)
    # S_r -> r singular values (top r)
    # Vh_r -> r x d matrix (top r right singular vectors transposed)
    U_r = U[:, :r]
    S_r = S[:r]
    Vh_r = Vh[:r, :]

    # Compute Sigma_r^(1/2) as a diagonal matrix with the square roots of S_r.
    # Since S_r contains nonnegative singular values, taking the square root works elementwise.
    sqrt_S_r = torch.sqrt(S_r)
    Sigma_r_half = torch.diag(sqrt_S_r)

    # Form the optimal factors:
    # X_opt = U_r * Sigma_r^(1/2)
    # Y_opt = Sigma_r^(1/2) * V_r^T. Note: V_r^T is given by Vh_r.
    R = U_r @ Sigma_r_half
    L = Sigma_r_half @ Vh_r

    return L.to(dtype=W.dtype), R.to(dtype=W.dtype)

# %%
def draw(W):
    # abs_w = W.abs().view(-1).cpu().numpy()
    plt.figure(figsize=(6, 3))
    plt.hist(W.to(torch.float).view(-1).cpu().numpy(), bins=200, log=True, color="#1f77b4")
    plt.title("Histogram of |W| with 0.05% extreme outliers")
    plt.xlabel("|w|")
    plt.ylabel("log10(count)")
    plt.tight_layout()

    save_path = "hist_outliers.png"
    plt.savefig(save_path, dpi=200)
    print(f"Figure saved to: {os.path.abspath(save_path)}")

def relativeError(a: torch.Tensor, b: torch.Tensor):
    return torch.norm(a - b, p="fro") / torch.norm(a, p="fro")

# %%
def check_outlier_restore(weight, sparsity_ratio=0.00005):
    in_d = weight.shape[1]
    out_d = weight.shape[0]
    
    compute_dtype = torch.bfloat16
    linear = torch.nn.Linear(in_d, out_d, bias=False, dtype=compute_dtype).to("cuda")
    linear.requires_grad_(False)
    device = linear.weight.device
    linear.weight.copy_(weight.to(compute_dtype).contiguous())
    
    # draw the weight before pruning
    draw(linear.weight.data)
    
    x = torch.randn(4096,in_d, dtype=compute_dtype).to("cuda")
    golden_output = linear(x)

    # quantize the weight
    weight_bf16 = linear.weight.detach().to(compute_dtype).contiguous()
    bias = None if linear.bias is None else linear.bias.detach().clone()

    qlinear = bnb.nn.Linear4bit(
        in_d,
        out_d,
        bias=bias is not None,
        compute_dtype=compute_dtype,
        quant_type="fp4",
    ).to(device)

    qlinear.weight = bnb.nn.Params4bit(
        weight_bf16,
        requires_grad=False,
        quant_type="fp4",
    ).to(device)
    if bias is not None:
        qlinear.bias = nn.Parameter(bias)

    quantized_output = qlinear(x)
    
    # prune the weight (only the largest 0.00005% weights for outlier restoration)
    sparse_mask = _get_mask_prune_magnitude(weight_bf16, sparsity_ratio=sparsity_ratio, prune_n=0, prune_m=0, largest=True, offload=False)
    print(sparse_mask.sum().item(), "sparse_mask sum")
    tmp_W = linear.weight.detach().to(compute_dtype).contiguous()
    linear.weight.data[sparse_mask.cuda()] = 0
    tmp_W = tmp_W - linear.weight.data
    WL, WR = decomposeW2LinearWeightLR(
                tmp_W,
                16,
            )
    WL_linear = nn.Linear(WL.shape[1], WL.shape[0], bias=False, dtype=compute_dtype).to(device)
    WL_linear.weight.data.copy_(WL)
    WR_linear = nn.Linear(WR.shape[1], WR.shape[0], bias=False, dtype=compute_dtype).to(device)
    WR_linear.weight.data.copy_(WR)
    sparse_weight_bf16 = linear.weight.detach().to(compute_dtype).contiguous()
    
    # draw the weight after pruning
    # draw(linear.weight.data)
    
    qlinear_wo_outlier = bnb.nn.Linear4bit(
        in_d,
        out_d,
        bias=bias is not None,
        compute_dtype=compute_dtype,
        quant_type="nf4",
    ).to(device)

    qlinear_wo_outlier.weight = bnb.nn.Params4bit(
        sparse_weight_bf16,
        requires_grad=False,
        quant_type="nf4",
    ).to(device)

    quantized_output_wo_outlier = qlinear_wo_outlier(x) + WR_linear(WL_linear(x))
    
    relativeError_value = relativeError(golden_output, quantized_output)
    relativeError_value_wo_outlier = relativeError(golden_output, quantized_output_wo_outlier)

    return relativeError_value, relativeError_value_wo_outlier

# %%
# this is for visualization of the initial weight
ckpts = {"llama2":["/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Llama-2-7b-chat-hf/model-00001-of-00002.safetensors", "/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Llama-2-7b-chat-hf/model-00002-of-00002.safetensors"], "llama3":["/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Meta-Llama-3-8B-Instruct/model-00001-of-00004.safetensors","/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Meta-Llama-3-8B-Instruct/model-00002-of-00004.safetensors","/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Meta-Llama-3-8B-Instruct/model-00003-of-00004.safetensors","/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Meta-Llama-3-8B-Instruct/model-00004-of-00004.safetensors"]}

for model in ["llama2", "llama3"]:
    e1s = []
    e2s = []
    for ckpt in ckpts[model]:
        safetensors = load_file(ckpt)
        for key, value in safetensors.items():
            if "self_attn" in key or "mlp" in key:
                if len(value.shape) != 2:
                    continue
                # u_opt, t_opt, rho_opt, sigma_est = optimal_sparsity_from_weights(value, k=4, eps_tail=None, return_stats=True)
                # print(f"Estimated σ = {sigma_est:.4f}")
                # print(f"Optimal u* = {u_opt:.4f}")
                # print(f"Prune threshold t* = σ·u* = {t_opt:.4f}")
                # print(f"Optimal sparsity ρ* = {rho_opt*100:.3f}%")
                for sparse_ratio in [0.000001]:
                    e1, e2 = check_outlier_restore(value.to("cuda"), sparsity_ratio=sparse_ratio)
                    print(f"Relative error for {key}: {e1.item()} (with outliers), {e2.item()} (without outliers)")
                    e1s.append(e1)
                    e2s.append(e2)
    avg_diff = (sum(e1s) - sum(e2s)) / len(e1s)
    print(f"Average difference for {model}: {avg_diff.item()}")
    torch.cuda.empty_cache()
# Out:
# Estimated σ = 0.0167
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0538
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.0.mlp.down_proj.weight: 0.1240234375 (with outliers), 0.09521484375 (without outliers)
# Estimated σ = 0.0163
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0525
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.0.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0160
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0516
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.0.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0150
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0483
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.0.self_attn.k_proj.weight: 0.185546875 (with outliers), 0.1279296875 (without outliers)
# Estimated σ = 0.0071
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0230
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.0.self_attn.o_proj.weight: 0.142578125 (with outliers), 0.11376953125 (without outliers)
# Estimated σ = 0.0134
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0432
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.0.self_attn.q_proj.weight: 0.193359375 (with outliers), 0.1357421875 (without outliers)
# Estimated σ = 0.0110
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0354
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.0.self_attn.v_proj.weight: 0.12451171875 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0173
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0557
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.1.mlp.down_proj.weight: 0.123046875 (with outliers), 0.09912109375 (without outliers)
# Estimated σ = 0.0181
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0583
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.1.mlp.gate_proj.weight: 0.123046875 (with outliers), 0.0986328125 (without outliers)
# Estimated σ = 0.0170
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0549
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.1.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0262
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0845
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.1.self_attn.k_proj.weight: 0.1318359375 (with outliers), 0.09814453125 (without outliers)
# Estimated σ = 0.0082
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0265
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.1.self_attn.o_proj.weight: 0.1337890625 (with outliers), 0.1103515625 (without outliers)
# Estimated σ = 0.0262
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0846
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.1.self_attn.q_proj.weight: 0.1318359375 (with outliers), 0.0966796875 (without outliers)
# Estimated σ = 0.0100
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0322
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.1.self_attn.v_proj.weight: 0.125 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0177
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0570
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 49 sparse_mask sum
# Relative error for model.layers.10.mlp.down_proj.weight: 0.123046875 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0191
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0617
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.10.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0178
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0576
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.10.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0257
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0828
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.10.self_attn.k_proj.weight: 0.123046875 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0141
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0456
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.10.self_attn.o_proj.weight: 0.12158203125 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0249
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0803
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.10.self_attn.q_proj.weight: 0.123046875 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0142
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0460
# Optimal sparsity ρ* = 0.126%
# /tmp/ipykernel_1673265/2230803599.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(6, 3))
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.10.self_attn.v_proj.weight: 0.1220703125 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0178
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0574
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.11.mlp.down_proj.weight: 0.123046875 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0190
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0614
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.11.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0180
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0581
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.11.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0236
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0761
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.11.self_attn.k_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0147
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0474
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.11.self_attn.o_proj.weight: 0.12255859375 (with outliers), 0.09814453125 (without outliers)
# Estimated σ = 0.0237
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0763
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.11.self_attn.q_proj.weight: 0.12353515625 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0149
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0479
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.11.self_attn.v_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0179
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0579
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.12.mlp.down_proj.weight: 0.123046875 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0189
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0611
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.12.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0182
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0586
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.12.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0249
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0803
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.12.self_attn.k_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0145
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0469
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.12.self_attn.o_proj.weight: 0.12255859375 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0241
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0779
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 19 sparse_mask sum
# Relative error for model.layers.12.self_attn.q_proj.weight: 0.12353515625 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0147
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0473
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.12.self_attn.v_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0181
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0583
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.13.mlp.down_proj.weight: 0.123046875 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0189
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0608
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.13.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0183
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0592
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.13.mlp.up_proj.weight: 0.1220703125 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0243
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0785
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.13.self_attn.k_proj.weight: 0.123046875 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0151
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0486
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.13.self_attn.o_proj.weight: 0.1220703125 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0239
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0771
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.13.self_attn.q_proj.weight: 0.123046875 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0152
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0490
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.13.self_attn.v_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0181
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0584
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.14.mlp.down_proj.weight: 0.123046875 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0188
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0607
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.14.mlp.gate_proj.weight: 0.1220703125 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0184
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0593
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.14.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0243
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0784
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.14.self_attn.k_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0148
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0476
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.14.self_attn.o_proj.weight: 0.1220703125 (with outliers), 0.09619140625 (without outliers)
# Estimated σ = 0.0239
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0770
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.14.self_attn.q_proj.weight: 0.123046875 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0149
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0481
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.14.self_attn.v_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0182
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0586
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.15.mlp.down_proj.weight: 0.123046875 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0189
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0610
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 48 sparse_mask sum
# Relative error for model.layers.15.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0185
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0596
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.15.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0244
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0786
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 19 sparse_mask sum
# Relative error for model.layers.15.self_attn.k_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0153
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0494
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.15.self_attn.o_proj.weight: 0.1220703125 (with outliers), 0.09521484375 (without outliers)
# Estimated σ = 0.0236
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0760
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.15.self_attn.q_proj.weight: 0.123046875 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0155
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0501
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.15.self_attn.v_proj.weight: 0.123046875 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0182
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0586
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.16.mlp.down_proj.weight: 0.123046875 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0190
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0614
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.16.mlp.gate_proj.weight: 0.1220703125 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0185
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0595
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.16.mlp.up_proj.weight: 0.1220703125 (with outliers), 0.09228515625 (without outliers)
# Estimated σ = 0.0240
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0775
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.16.self_attn.k_proj.weight: 0.12353515625 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0160
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0516
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.16.self_attn.o_proj.weight: 0.1220703125 (with outliers), 0.09521484375 (without outliers)
# Estimated σ = 0.0234
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0754
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.16.self_attn.q_proj.weight: 0.12353515625 (with outliers), 0.0966796875 (without outliers)
# Estimated σ = 0.0162
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0522
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.16.self_attn.v_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0181
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0585
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.17.mlp.down_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0192
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0620
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.17.mlp.gate_proj.weight: 0.1220703125 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0184
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0593
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.17.mlp.up_proj.weight: 0.1220703125 (with outliers), 0.09228515625 (without outliers)
# Estimated σ = 0.0237
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0765
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.17.self_attn.k_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0160
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0517
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.17.self_attn.o_proj.weight: 0.1220703125 (with outliers), 0.09619140625 (without outliers)
# Estimated σ = 0.0232
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0749
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.17.self_attn.q_proj.weight: 0.123046875 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0161
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0520
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.17.self_attn.v_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0181
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0585
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.18.mlp.down_proj.weight: 0.12255859375 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0194
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0626
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.18.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0183
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0591
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.18.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0232
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0748
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.18.self_attn.k_proj.weight: 0.123046875 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0166
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0537
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.18.self_attn.o_proj.weight: 0.1220703125 (with outliers), 0.09619140625 (without outliers)
# Estimated σ = 0.0227
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0732
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.18.self_attn.q_proj.weight: 0.123046875 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0169
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0544
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.18.self_attn.v_proj.weight: 0.1220703125 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0182
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0586
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 49 sparse_mask sum
# Relative error for model.layers.19.mlp.down_proj.weight: 0.12255859375 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0195
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0628
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.19.mlp.gate_proj.weight: 0.1220703125 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0183
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0591
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 48 sparse_mask sum
# Relative error for model.layers.19.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0228
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0737
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.19.self_attn.k_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0168
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0543
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.19.self_attn.o_proj.weight: 0.1220703125 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0224
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0723
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.19.self_attn.q_proj.weight: 0.12353515625 (with outliers), 0.09619140625 (without outliers)
# Estimated σ = 0.0170
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0549
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.19.self_attn.v_proj.weight: 0.123046875 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0174
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0562
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.2.mlp.down_proj.weight: 0.123046875 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0186
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0599
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.2.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0173
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0559
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.2.mlp.up_proj.weight: 0.1220703125 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0278
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0895
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.2.self_attn.k_proj.weight: 0.125 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0138
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0445
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.2.self_attn.o_proj.weight: 0.12255859375 (with outliers), 0.09912109375 (without outliers)
# Estimated σ = 0.0264
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0851
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.2.self_attn.q_proj.weight: 0.1259765625 (with outliers), 0.0966796875 (without outliers)
# Estimated σ = 0.0142
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0459
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.2.self_attn.v_proj.weight: 0.123046875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0182
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0586
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.20.mlp.down_proj.weight: 0.12255859375 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0196
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0631
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.20.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0183
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0591
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.20.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0230
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0741
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.20.self_attn.k_proj.weight: 0.12353515625 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0172
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0554
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.20.self_attn.o_proj.weight: 0.12158203125 (with outliers), 0.09619140625 (without outliers)
# Estimated σ = 0.0226
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0728
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.20.self_attn.q_proj.weight: 0.12353515625 (with outliers), 0.09765625 (without outliers)
# Estimated σ = 0.0173
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0557
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 19 sparse_mask sum
# Relative error for model.layers.20.self_attn.v_proj.weight: 0.123046875 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0182
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0586
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.21.mlp.down_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0197
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0636
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.21.mlp.gate_proj.weight: 0.1220703125 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0183
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0590
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.21.mlp.up_proj.weight: 0.1220703125 (with outliers), 0.09228515625 (without outliers)
# Estimated σ = 0.0223
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0719
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.21.self_attn.k_proj.weight: 0.12451171875 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0176
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0566
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 19 sparse_mask sum
# Relative error for model.layers.21.self_attn.o_proj.weight: 0.12158203125 (with outliers), 0.09521484375 (without outliers)
# Estimated σ = 0.0221
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0712
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.21.self_attn.q_proj.weight: 0.12451171875 (with outliers), 0.09716796875 (without outliers)
# Estimated σ = 0.0178
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0574
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.21.self_attn.v_proj.weight: 0.12255859375 (with outliers), 0.09228515625 (without outliers)
# Estimated σ = 0.0182
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0586
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.22.mlp.down_proj.weight: 0.12255859375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0198
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0639
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.22.mlp.gate_proj.weight: 0.1220703125 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0183
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0590
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.22.mlp.up_proj.weight: 0.1220703125 (with outliers), 0.09228515625 (without outliers)
# Estimated σ = 0.0228
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0736
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.22.self_attn.k_proj.weight: 0.12353515625 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0176
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0568
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.22.self_attn.o_proj.weight: 0.12255859375 (with outliers), 0.1005859375 (without outliers)
# Estimated σ = 0.0225
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0727
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.22.self_attn.q_proj.weight: 0.12353515625 (with outliers), 0.09716796875 (without outliers)
# Estimated σ = 0.0179
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0577
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.22.self_attn.v_proj.weight: 0.12255859375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0183
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0589
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.23.mlp.down_proj.weight: 0.1220703125 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0198
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0639
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.23.mlp.gate_proj.weight: 0.1220703125 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0184
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0592
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.23.mlp.up_proj.weight: 0.1220703125 (with outliers), 0.09228515625 (without outliers)
# Estimated σ = 0.0225
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0727
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.23.self_attn.k_proj.weight: 0.12353515625 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0185
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0596
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.23.self_attn.o_proj.weight: 0.12255859375 (with outliers), 0.09521484375 (without outliers)
# Estimated σ = 0.0224
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0722
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.23.self_attn.q_proj.weight: 0.12353515625 (with outliers), 0.0966796875 (without outliers)
# Estimated σ = 0.0187
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0604
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 18 sparse_mask sum
# Relative error for model.layers.23.self_attn.v_proj.weight: 0.12255859375 (with outliers), 0.09228515625 (without outliers)
# Estimated σ = 0.0175
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0564
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.3.mlp.down_proj.weight: 0.123046875 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0188
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0608
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.3.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0174
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0563
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.3.mlp.up_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0260
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0838
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.3.self_attn.k_proj.weight: 0.1240234375 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0132
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0426
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.3.self_attn.o_proj.weight: 0.12255859375 (with outliers), 0.09814453125 (without outliers)
# Estimated σ = 0.0250
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0806
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.3.self_attn.q_proj.weight: 0.1259765625 (with outliers), 0.0966796875 (without outliers)
# Estimated σ = 0.0135
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0436
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.3.self_attn.v_proj.weight: 0.1220703125 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0173
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0557
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.4.mlp.down_proj.weight: 0.123046875 (with outliers), 0.09619140625 (without outliers)
# Estimated σ = 0.0192
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0621
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.4.mlp.gate_proj.weight: 0.123046875 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0173
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0559
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.4.mlp.up_proj.weight: 0.1220703125 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0266
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0858
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.4.self_attn.k_proj.weight: 0.12451171875 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0139
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0450
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.4.self_attn.o_proj.weight: 0.1220703125 (with outliers), 0.09814453125 (without outliers)
# Estimated σ = 0.0260
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0840
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.4.self_attn.q_proj.weight: 0.125 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0143
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0460
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.4.self_attn.v_proj.weight: 0.1220703125 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0173
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0558
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 46 sparse_mask sum
# Relative error for model.layers.5.mlp.down_proj.weight: 0.1220703125 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0194
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0624
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.5.mlp.gate_proj.weight: 0.12255859375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0173
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0559
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 47 sparse_mask sum
# Relative error for model.layers.5.mlp.up_proj.weight: 0.1220703125 (with outliers), 0.09326171875 (without outliers)
# ...
# Estimated σ = 0.0078
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0250
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.2.self_attn.o_proj.weight: 0.1240234375 (with outliers), 0.09765625 (without outliers)
# Estimated σ = 0.0174
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0563
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.2.self_attn.q_proj.weight: 0.1298828125 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0065
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0210
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 5 sparse_mask sum
# Relative error for model.layers.2.self_attn.v_proj.weight: 0.1240234375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0104
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0334
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 60 sparse_mask sum
# Relative error for model.layers.3.mlp.down_proj.weight: 0.12353515625 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0128
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0412
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 62 sparse_mask sum
# Relative error for model.layers.3.mlp.gate_proj.weight: 0.12353515625 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0104
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0335
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 59 sparse_mask sum
# Relative error for model.layers.3.mlp.up_proj.weight: 0.12353515625 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0268
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0863
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 5 sparse_mask sum
# Relative error for model.layers.3.self_attn.k_proj.weight: 0.12451171875 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0089
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0286
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.3.self_attn.o_proj.weight: 0.12255859375 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0175
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0565
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.3.self_attn.q_proj.weight: 0.1240234375 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0077
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0249
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 5 sparse_mask sum
# Relative error for model.layers.3.self_attn.v_proj.weight: 0.1240234375 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0101
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0326
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 59 sparse_mask sum
# Relative error for model.layers.4.mlp.down_proj.weight: 0.1240234375 (with outliers), 0.095703125 (without outliers)
# Estimated σ = 0.0135
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0434
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 59 sparse_mask sum
# Relative error for model.layers.4.mlp.gate_proj.weight: 0.1240234375 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0101
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0326
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 60 sparse_mask sum
# Relative error for model.layers.4.mlp.up_proj.weight: 0.1240234375 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0263
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0849
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 6 sparse_mask sum
# Relative error for model.layers.4.self_attn.k_proj.weight: 0.1279296875 (with outliers), 0.09521484375 (without outliers)
# Estimated σ = 0.0091
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0292
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.4.self_attn.o_proj.weight: 0.12353515625 (with outliers), 0.09619140625 (without outliers)
# Estimated σ = 0.0173
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0558
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.4.self_attn.q_proj.weight: 0.1259765625 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0083
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0269
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 5 sparse_mask sum
# Relative error for model.layers.4.self_attn.v_proj.weight: 0.123046875 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0101
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0327
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 60 sparse_mask sum
# Relative error for model.layers.5.mlp.down_proj.weight: 0.1240234375 (with outliers), 0.0966796875 (without outliers)
# Estimated σ = 0.0135
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0434
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 59 sparse_mask sum
# Relative error for model.layers.5.mlp.gate_proj.weight: 0.1240234375 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0102
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0328
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 60 sparse_mask sum
# Relative error for model.layers.5.mlp.up_proj.weight: 0.12353515625 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0264
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0852
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 5 sparse_mask sum
# Relative error for model.layers.5.self_attn.k_proj.weight: 0.1298828125 (with outliers), 0.09716796875 (without outliers)
# Estimated σ = 0.0084
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0271
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.5.self_attn.o_proj.weight: 0.123046875 (with outliers), 0.09619140625 (without outliers)
# Estimated σ = 0.0172
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0555
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.5.self_attn.q_proj.weight: 0.126953125 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0069
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0223
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 5 sparse_mask sum
# Relative error for model.layers.5.self_attn.v_proj.weight: 0.1240234375 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0101
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0327
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 59 sparse_mask sum
# Relative error for model.layers.6.mlp.down_proj.weight: 0.1240234375 (with outliers), 0.09716796875 (without outliers)
# Estimated σ = 0.0135
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0437
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 60 sparse_mask sum
# Relative error for model.layers.6.mlp.gate_proj.weight: 0.123046875 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0102
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0328
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 59 sparse_mask sum
# Relative error for model.layers.6.mlp.up_proj.weight: 0.12353515625 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0264
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0851
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 5 sparse_mask sum
# Relative error for model.layers.6.self_attn.k_proj.weight: 0.12451171875 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0088
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0282
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.6.self_attn.o_proj.weight: 0.123046875 (with outliers), 0.09716796875 (without outliers)
# Estimated σ = 0.0175
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0566
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.6.self_attn.q_proj.weight: 0.1240234375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0075
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0242
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 5 sparse_mask sum
# Relative error for model.layers.6.self_attn.v_proj.weight: 0.12353515625 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0103
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0332
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 60 sparse_mask sum
# Relative error for model.layers.7.mlp.down_proj.weight: 0.125 (with outliers), 0.09765625 (without outliers)
# Estimated σ = 0.0133
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0429
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 61 sparse_mask sum
# Relative error for model.layers.7.mlp.gate_proj.weight: 0.12353515625 (with outliers), 0.09423828125 (without outliers)
# Estimated σ = 0.0103
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0333
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 61 sparse_mask sum
# Relative error for model.layers.7.mlp.up_proj.weight: 0.1240234375 (with outliers), 0.09375 (without outliers)
# Estimated σ = 0.0266
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0859
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 6 sparse_mask sum
# Relative error for model.layers.7.self_attn.k_proj.weight: 0.1240234375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0089
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0287
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.7.self_attn.o_proj.weight: 0.12255859375 (with outliers), 0.0947265625 (without outliers)
# Estimated σ = 0.0168
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0543
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 17 sparse_mask sum
# Relative error for model.layers.7.self_attn.q_proj.weight: 0.1240234375 (with outliers), 0.09326171875 (without outliers)
# Estimated σ = 0.0075
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0240
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 5 sparse_mask sum
# Relative error for model.layers.7.self_attn.v_proj.weight: 0.1240234375 (with outliers), 0.0927734375 (without outliers)
# Estimated σ = 0.0103
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0331
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# 59 sparse_mask sum
# Relative error for model.layers.8.mlp.down_proj.weight: 0.1240234375 (with outliers), 0.09765625 (without outliers)
# Estimated σ = 0.0134
# Optimal u* = 3.2258
# Prune threshold t* = σ·u* = 0.0431
# Optimal sparsity ρ* = 0.126%
# Figure saved to: /mnt/sdb/zhanglongteng/workspace/llm-toolkit/tmp/check_outlier_restore/hist_outliers.png
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[25], line 19
#      17 print(f"Optimal sparsity ρ* = {rho_opt*100:.3f}%")
#      18 for sparse_ratio in [0.000001]:
# ---> 19     e1, e2 = check_outlier_restore(value.to("cuda"), sparsity_ratio=sparse_ratio)
#      20     print(f"Relative error for {key}: {e1.item()} (with outliers), {e2.item()} (without outliers)")
#      21     e1s.append(e1)
#
# Cell In[23], line 40, in check_outlier_restore(weight, sparsity_ratio)
#      37 quantized_output = qlinear(x)
#      39 # prune the weight (only the largest 0.00005% weights for outlier restoration)
# ---> 40 sparse_mask = _get_mask_prune_magnitude(weight_bf16, sparsity_ratio=sparsity_ratio, prune_n=0, prune_m=0, largest=True, offload=False)
#      41 print(sparse_mask.sum().item(), "sparse_mask sum")
#      42 tmp_W = linear.weight.detach().to(compute_dtype).contiguous()
#
# File ~/anaconda3/envs/workspace/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[2], line 24, in _get_mask_prune_magnitude(W, sparsity_ratio, prune_n, prune_m, largest, offload)
#      22 else:
#      23     if largest:
# ---> 24         thresh = torch.sort(W_metric.flatten(), descending=True)[0][int(W.numel() * sparsity_ratio)].cpu()
#      25         W_mask = W_metric >= thresh
#      26     else:
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 562.00 MiB. GPU 0 has a total capacity of 47.54 GiB of which 256.38 MiB is free. Including non-PyTorch memory, this process has 47.27 GiB memory in use. Of the allocated memory 44.38 GiB is allocated by PyTorch, and 2.54 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
def phi(u):
    """Standard Gaussian PDF at u."""
    return math.exp(-0.5 * u*u) / math.sqrt(2*math.pi)

def Phi(u):
    """Standard Gaussian CDF at u."""
    return 0.5 * (1 + math.erf(u / math.sqrt(2)))

def find_optimal_u(L, tol=1e-7, max_u=10.0, eps_tail=None):
    """
    Solve for u>0 in
       Dg(u) = Do(u) * eps_tail(u)
    where
       Dg(u) = u^2 / (3 L^2)
       Do(u) = 2 [u*phi(u) + (1 - Phi(u))]
    If eps_tail is None, it solves Dg(u)=Do(u).
    """
    def Dg(u):
        return (u*u) / (3 * L * L)
    def Do(u):
        return 2 * (u * phi(u) + (1 - Phi(u)))
    def f(u):
        if eps_tail is None:
            return Dg(u) - Do(u)
        else:
            return Dg(u) - Do(u) * eps_tail(u)

    a, b = 1e-9, max_u
    fa, fb = f(a), f(b)
    if fa * fb > 0:
        raise RuntimeError(f"f(a)={fa:.3e}, f(b)={fb:.3e} same sign; increase max_u")

    # Bisection
    while b - a > tol:
        m = 0.5 * (a + b)
        fm = f(m)
        if fa * fm <= 0:
            b, fb = m, fm
        else:
            a, fa = m, fm
    return 0.5 * (a + b)

def optimal_sparsity_from_weights(W,
                                  k=4,
                                  eps_tail=None,
                                  return_stats=False):
    """
    Given a weight matrix W (torch.Tensor or np.ndarray):
      - estimates sigma = std(W)
      - solves for u* with k‐bit quantization (L=2^k−1 levels)
      - returns (u*, t*=sigma*u*, rho*=2[1-Phi(u*)])
    If eps_tail(u) is provided, it should be a function u-> [0,1] giving the
    fraction of tail‐energy *not* recovered by your rank‐r path.
    If return_stats=True, also returns the estimated sigma.
    """
    # 1) Convert to torch CPU float and estimate std
    if not isinstance(W, torch.Tensor):
        W = torch.tensor(W)
    W_cpu = W.detach().cpu().to(torch.float32)
    sigma = float(W_cpu.std(unbiased=True).item())

    # 2) Solve for u*
    L = 2**k - 1
    u_star = find_optimal_u(L, eps_tail=eps_tail)

    # 3) Compute threshold & sparsity ratio
    t_star = sigma * u_star
    rho_star = 2 * (1 - Phi(u_star))

    if return_stats:
        return u_star, t_star, rho_star, sigma
    else:
        return u_star, t_star, rho_star

# %%
# deprecated
# this is for visualization of the pruned weight
ckpts = {"llama2":["/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Llama-2-7b-chat-hf/model-00001-of-00002.safetensors", "/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Llama-2-7b-chat-hf/model-00002-of-00002.safetensors"], "llama3":["/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Meta-Llama-3-8B-Instruct/model-00001-of-00004.safetensors","/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Meta-Llama-3-8B-Instruct/model-00002-of-00004.safetensors","/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Meta-Llama-3-8B-Instruct/model-00003-of-00004.safetensors","/mnt/sdb/zhanglongteng/sdd/zhanglongteng/Meta-Llama-3-8B-Instruct/model-00004-of-00004.safetensors"]}

for model in ["llama2", "llama3"]:
    e1s = []
    e2s = []
    for ckpt in ckpts[model]:
        safetensors = load_file(ckpt)
        for key, value in safetensors.items():
            if "self_attn" in key or "mlp" in key:
                if len(value.shape) != 2:
                    continue
                e1, e2 = check_outlier_restore(value.to("cuda"))
                print(f"Relative error for {key}: {e1.item()} (with outliers), {e2.item()} (without outliers)")
                e1s.append(e1)
                e2s.append(e2)
    avg_diff = (sum(e1s) - sum(e2s)) / len(e1s)
    print(f"Average difference for {model}: {avg_diff.item()}")
    torch.cuda.empty_cache()

# %%
def make_extreme_outlier_weight(
        rows:int = 4096,
        cols:int = 4096,
        pct_outlier: float = 0.0005,
        outlier_mag: float = 30.0,
        seed: int = 42
    ) -> torch.Tensor:
    torch.manual_seed(seed)

    W = torch.randn(rows, cols, dtype = torch.bfloat16, device="cuda")

    # randperm
    num_outliers = int(rows * cols * pct_outlier)
    flat_idx = torch.randperm(rows * cols)[:num_outliers]

    # = +-30
    W.view(-1)[flat_idx[:num_outliers // 2]]  =  outlier_mag
    W.view(-1)[flat_idx[num_outliers // 2:]] = -outlier_mag

    return W

check_outlier_restore(make_extreme_outlier_weight())
